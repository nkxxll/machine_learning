# %%
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np
data = pd.read_csv("../data/exam-iq.csv")
sns.scatterplot(x=data.Hours, y=data.IQ, hue=data.Pass)
# Out:
# <Axes: xlabel='Hours', ylabel='IQ'>

# %%
model = LogisticRegression(random_state=0)
features = ["Hours", "IQ"]
X = data[features].to_numpy(copy=True)
y = np.array(data.Pass)
model.fit(X, y)
model.score(X, y)
y_pred = model.predict(X)

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_true=y, y_pred=y_pred)
# Out:
# (array([0.81818182, 0.88888889]),
#  array([0.9, 0.8]),
#  array([0.85714286, 0.84210526]),
#  array([10, 10]))
